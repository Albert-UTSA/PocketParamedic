# %%
import os

# Change to the YOLOv5 directory
os.chdir('C:\\Users\\Anti\\Documents\\AI_ML_CLASS\\YOLOV2\\yolov5')
# Check current working directory again
print("New Current Directory:", os.getcwd())
# Out:
# New Current Directory: C:\Users\Anti\Documents\AI_ML_CLASS\YOLOV2\yolov5

# %%
from utils.plots import plot_results  # plot results.txt as results.png
from IPython.display import Image  # to display images

# View results.png
Image(filename='C:\\Users\\Anti\\Downloads\\yolov5\\runs\\train\\yolov5s_results\\results.png', width=1000)

# View validation batch image
Image(filename='C:\\Users\\Anti\\Downloads\\yolov5\\runs\\train\\yolov5s_results\\val_batch0_labels.jpg', width=900)

# Print out an augmented training example
print("GROUND TRUTH AUGMENTED TRAINING DATA:")
Image(filename='C:\\Users\\Anti\\Downloads\\yolov5\\runs\\train\\yolov5s_results\\train_batch0.jpg', width=900)
# Out:
# GROUND TRUTH AUGMENTED TRAINING DATA:

# %%
import os

# List contents in the runs directory
print(os.listdir('C:\\Users\\Anti\\Documents\\AI_ML_CLASS\\YOLOV2\\yolov5\\runs'))

# List contents in the specific training results directory
print(os.listdir('C:\\Users\\Anti\\Documents\\AI_ML_CLASS\\YOLOV2\\yolov5\\runs\\train\\yolov5s_results\\weights'))

# Change directory in Jupyter/IPython
# %cd C:\\Users\\Anti\\Documents\\AI_ML_CLASS\\YOLOV2\\yolov5\\

# Run the detection script
# !python detect.py --weights runs\\train\\yolov5s_results\\weights\\best.pt --img 416 --conf 0.25 --source Project-Pocket-Paramedic-1\\test\\images\\
# Out:
# ['detect', 'train']
# ['best.pt', 'last.pt', 'OLDbest.pt']
# C:\Users\Anti\Documents\AI_ML_CLASS\YOLOV2\yolov5
# detect: weights=['runs\\\\train\\\\yolov5s_results\\\\weights\\\\best.pt'], source=Project-Pocket-Paramedic-1\\test\\images\\, data=data\coco128.yaml, imgsz=[416, 416], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs\detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5  v7.0-72-g064365d8 Python-3.12.3 torch-2.2.2+cu121 CUDA:0 (NVIDIA GeForce RTX 4090 Laptop GPU, 16376MiB)
#
# Fusing layers...
# custom_YOLOv5s summary: 182 layers, 7246518 parameters, 0 gradients
# Traceback (most recent call last):
#   File "C:\Users\Anti\Documents\AI_ML_CLASS\YOLOV2\yolov5\detect.py", line 261, in <module>
#     main(opt)
# ...

# %%
import torch

print('Setup complete. Using torch %s %s' % (torch.__version__, torch.cuda.get_device_properties(0) if torch.cuda.is_available() else 'CPU'))
# Out:
# Setup complete. Using torch 2.2.2+cu121 _CudaDeviceProperties(name='NVIDIA GeForce RTX 4090 Laptop GPU', major=8, minor=9, total_memory=16375MB, multi_processor_count=76)

# %%
# Change directory in Jupyter/IPython
# %cd C:\\Users\\Anti\\Documents\\AI_ML_CLASS\\YOLOV2\\yolov5\\

# Run the detection script
# !python detect.py --weights runs\\train\\yolov5s_results\\weights\\best.pt --img 416 --conf 0.25 --source Project-Pocket-Paramedic-1\\test\\images\\
# Out:
# C:\Users\Anti\Documents\AI_ML_CLASS\YOLOV2\yolov5
# detect: weights=['runs\\\\train\\\\yolov5s_results\\\\weights\\\\best.pt'], source=Project-Pocket-Paramedic-1\\test\\images\\, data=data\coco128.yaml, imgsz=[416, 416], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs\detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5  v7.0-72-g064365d8 Python-3.12.3 torch-2.2.2+cu121 CUDA:0 (NVIDIA GeForce RTX 4090 Laptop GPU, 16376MiB)
#
# Fusing layers...
# custom_YOLOv5s summary: 182 layers, 7246518 parameters, 0 gradients
# Traceback (most recent call last):
#   File "C:\Users\Anti\Documents\AI_ML_CLASS\YOLOV2\yolov5\detect.py", line 261, in <module>
#     main(opt)
# ...

# %%
import glob
from IPython.display import Image, display

# Adjust the path to match the location where your images are saved
for imageName in glob.glob('C:\\Users\\Anti\\Documents\\AI_ML_CLASS\\YOLOV2\\yolov5\\runs\\detect\\exp2\\*.jpg')[:20]: # assuming JPG
#for imageName in glob.glob('C:\\Users\\Anti\\Documents\\AI_ML_CLASS\\YOLOV2\\yolov5\\runs\\detect\\CAMERA_IMAGES\\*.jpg')[:20]: # assuming JPG

    display(Image(filename=imageName))
